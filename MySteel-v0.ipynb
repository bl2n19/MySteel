# %%
from urllib.request import urlopen
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
# %matplotlib inline

# %%
url = "https://info.mybxg.com/m/20/1211/14/475723C27867937C.html"
html = urlopen(url)

# %%
soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
title = soup.title
print(title)
# Out:
# <title>【11日无锡2205热轧卷板行情价格_卷板的价格多少钱一吨/一斤_我的不锈钢网</title>

# %%
text = soup.get_text()
print(soup.text)
# Out:
# 【11日无锡2205热轧卷板行情价格_卷板的价格多少钱一吨/一斤_我的不锈钢网
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 首页|
#
# 不锈钢|
#
# 卷板
# 管材
# 带材
# 型材
#
#
#
# 镍系|
#
# 镍矿
# 镍铁
# 电解镍
# 硫酸镍
# 镍豆
# 电解钴
# 三元材料
#
#
#
# 铬系|
#
# 铬矿
# 铬铁
# 金属铬
#
#
#
# 废不锈钢|
#
#
#
#  价格行情 | 价格汇总 | 钢厂产量 | 钢厂调价 | 钢厂采购 | 市场库存 | 下周预测 | 成本估算 | APP
#
#
#
#
#
#
#
#
#
#
#
#
#
# 当前位置：首页 > 卷板价格 > 11日无锡2205热轧卷板行情价格
#
#
#
#
#
#
# 11日无锡2205热轧卷板行情价格
#
#             2020-12-11 14:56:22
#             来源：[ 我的不锈钢网 ]
#
#
#
#
#                     今日无锡市场2205热轧酒钢资源有所调涨，目前酒钢2205热轧主流报至19900元/吨，东特2205热轧主流报至18700元/吨。
#
#
# 查看全部↓
#
#
#
#
#
#
#
#                     钢种
# 请筛选
#
#
#
#
#
#                     规格
# 请筛选
#
#
#
#
#
#                     牌号
# 请筛选
#
#
#
#
#
#                     钢厂/产地
# 请筛选
#
#
#
#
#
#                     价格（元/吨）
#
#                     涨跌
#
#                     备注
#
#
#
# 当前筛选
#
#
#
#
#
#
#
#
#                                         卷板
#
#
#                                         3.0*1520*C
#
#
#                                         2205/NO.1
#
#
#                                         酒钢
#
#
#
#
#
#
#
#
#                                         毛边
#
#
#
#                                         卷板
#
#
#                                         4.0*1520*C
#
#
#                                         2205/NO.1
#
#
#                                         酒钢
#
#
#
#
#
#
#
#
#                                         毛边
#
#
#
#                                         卷板
#
#
#                                         5.0*1520*C
#
#
#                                         2205/NO.1
#
#
#                                         酒钢
#
#
#
#
#
#
#
#
#                                         毛边
#
#
#
#                                         卷板
#
#
#                                         6.0*1520*C
#
#
#                                         2205/NO.1
#
#
#                                         酒钢
#
#
#
#
#
#
#
#
#                                         毛边
#
#
#
#                                         卷板
#
#
#                                         4.0*1520*C
#
#
#                                         2205/NO.1
#
#
#                                         东方特钢
#
#
#
#
#
#
#
#
#                                         毛边
#
#
#
#                                         卷板
#
#
#                                         5.0*1520*C
#
#
#                                         2205/NO.1
#
#
#                                         东方特钢
#
#
#
#
#
#
#
#
#                                         毛边
#
#
#
#                                         卷板
#
#
#                                         6.0*1520*C
#
#
#                                         2205/NO.1
#
#
#                                         东方特钢
#
#
#
#
#
#
#
#
#                                         毛边
#
#
#
#                                         卷板
#
#
#                                         8.0*1520*C
#
#
#                                         2205/NO.1
#
#
#                                         东方特钢
#
#
#
#
#
#
#
#
#                                         毛边
#
#
#
#                                         卷板
#
#
#                                         10*1520*C
#
#
#                                         2205/NO.1
#
#
#                                         东方特钢
#
#
#
#
#
#
#
#
#                                         毛边
#
#
#
#                                         卷板
#
#
#                                         12*1520*C
#
#
#                                         2205/NO.1
#
#
#                                         东方特钢
#
#
#
#
#
#
#
#
#                                         毛边
#
#
#
#
#
#
#
#
#
#     资讯采集：王雨萌 021-26096715
#
#     资讯监督：魏铮 18688265167
#
#     资讯投诉：陈杰 021-26093100
#
# 免责声明：Mysteel力求使用的信息准确、信息所述内容及观点的客观公正，但并不保证其是否需要进行必要变更。Mysteel提供的信息仅供客户决策参考，并不构成对客户决策的直接建议，客户不应以此取代自己的独立判断，客户做出的任何决策与Mysteel无关。本报告版权归Mysteel所有，为非公开资料，仅供Mysteel客户自身使用；本文为Mysteel编辑，如需使用，请联系021-26093490申请授权，未经Mysteel书面授权，任何人不得以任何形式传播、发布、复制本报告。Mysteel保留对任何侵权行为和有悖报告原意的引用行为进行追究的权利。
#
#
#
#
# 热点推荐
#
# 找钢联国际，拿下更多钢材外贸订单！
#
#
#
#
#
#
#
#
# 相关行情
#
#
# [12-11]11日天津300系热轧卷板价格行情
# [12-11]11日沈阳300系热轧卷板价格行情
# [12-11]11日杭州300系热轧卷板价格行情
# [12-11]11日太原300系热轧卷板价格行情
# [12-11]11日佛山400系热轧价格行情
#
#
#
#
# 电子商务网钢铁资源
#
#
#
#
#
# 电子商务网全新开发，上电子商务网，免费发布钢铁资源
#
#
# 热门品种
#
# 冷轧卷板
# 热轧卷板
# 200系冷轧卷板
# 200系冷轧平板
# 200系热轧卷板
# 300系冷轧卷板
# 300系冷轧平板
# 300系热轧卷板
# 400系冷轧
# 400系热轧
# 热轧钢带
# 压延钢带
# 无缝管
# 不锈钢管坯
# 不锈钢工业焊管
# 不锈钢装饰焊管
# 不锈钢扁钢
# 不锈钢角钢
# 不锈钢圆钢
# 不锈钢槽钢
# 不锈钢线材
# 镍矿
# 镍铁
# 沪镍
# 硫酸镍
# 镍豆
# 三元材料
# 电解钴
# 铬矿
# 铬铁
#  金属铬
# 废不锈钢
#
#
#
#
#
#
#
#
# 行情推荐
#
#
# 不锈钢卷板：
#
# 冷轧卷板
# 热轧卷板
# 200系冷轧卷板
# 200系冷轧平板
# 200系热轧卷板
# 300系冷轧卷板
# 300系冷轧平板
# 300系热轧卷板
# 400系冷轧
# 400系热轧
#
#
#
# 不锈钢带材：
#
# 热轧钢带
# 压延钢带
#
#
#
# 不锈钢管材：
#
# 无缝管
# 不锈钢管坯
# 不锈钢工业焊管
# 不锈钢装饰焊管
#
#
#
# 不锈钢型材：
#
# 不锈钢扁钢
# 不锈钢角钢
# 不锈钢圆钢
# 不锈钢槽钢
# 不锈钢线材
#
#
#
# 镍系：
#
# 镍矿
# 镍铁
# 沪镍
# 硫酸镍
# 镍豆
# 三元材料
# 电解钴
#
#
#
# 铬系：
#
# 铬矿
# 铬铁
#  金属铬
#
#
#
# 废不锈钢
#
#
#
#
#
#
# 日评
#
# [12-14]Mysteel：20201214 废不锈钢日评
# [12-14]Mysteel：20201214不锈钢管型日评
# [12-14]Mysteel：202012014佛锡两地不锈钢卷板
# [12-14]Mysteel：20201214各省不锈钢卷板日评
# [12-11]Mysteel：202012011佛锡两地不锈钢卷板
# [12-11]Mysteel：20201211不锈钢管型日评
# [12-11]Mysteel：20201211 废不锈钢日评
# [12-11]Mysteel：20201211各省不锈钢卷板日评
# [12-10]Mysteel：202012010佛锡两地不锈钢卷板
#
#
#
#
#
# 价格汇总
#
# [12-15]15日全国主要城市304/2B卷板价格汇总
# [12-15]15日无锡不锈钢市场板卷价格汇总
# [12-15]15日全国主要城市304/NO.1卷板价格汇总
# [12-15]15日全国主要城市430/2B 卷板价格汇总
# [12-15]15日全国主要城市201/2B 卷板价格汇总
# [12-14]14日无锡不锈钢市场板卷价格汇总
# [12-14]14日全国主要城市201/2B 卷板价格汇总
# [12-14]14日全国主要城市304/NO.1卷板价格汇总
# [12-14]14日全国主要城市304/2B卷板价格汇总
#
#
#
#
#
# 热点导航
#
# 不锈钢指导价市场库存下周预测
# 进出口钢厂动态钢厂调价钢厂采购
# 直播日报周报月报研究报告
# 成本估算原料资讯产业数据
# 企业推荐现货资源头条轻工家电
# 餐厨行业交通运输房地产
#
#
#
# 品种推荐
#
# 螺纹钢
# 热卷
# 钢管
# 废钢
# 铁矿石
# 焦煤
# 焦炭
# 钢坯
# 不锈钢
# 镍
# 铁合金
# 硅锰
#
#
#
#
#
#
#
#
#
#
#
# 关于钢联 |
#     数据服务 |
#     联系我们 |
#     会员注册 |
#     技术支持 |
#     投资者关系 |
#     合作伙伴 |
#     服务报价
#     旗下网站：我的钢铁 |
#     我的不锈钢 |
#     我的有色 |
#     隆众石化 |
#     百年建筑 |
#     我的农产品 |
#     English |
#     研究咨询 |
#     搜搜钢 |
#     钢银现货交易 |
#     及韵物流 |
#     钢联能化
#     © 2000-2020 Mysteel.com, All Rights Reserved.
#     上海钢联电子商务股份有限公司 版权所有 上海大宗商品信息中心 增值电信业务经营许可证沪B2-20090056   沪ICP备15006920号-32
#
#
# 沪公网安备 31011302000793号
#
#
#
#
#
#
#
#
#
#
#
#
#
# 310104031210
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               意见反馈
#
#
#
#
#
# *类型:
#
#
#
#
#
# 资讯问题
#
#
#
#
# 问题报错
#
#
#
#
# 产品建议
#
#
#
#
#
# *反馈:
#
#
#
#
#
#
#
# 截图:
#
#
#
#
#
#
# 上传
#
#
#
#
#
#
#
# 姓名:
#
#
#
#
#
#
#
# *电话:
#
#
#
#
#
#
#
# *验证码:
#
#
#
#
#
#
#
#
#
#
#
# 提 交
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 你上传的格式错误！
#
# 确认
#
#
#
#
# 提交成功
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 微信
# 新浪微博
# QQ空间
# 打印
# 更多

# %%
rows = soup.find_all('tr')
for row in rows:
    row_td = row.find_all('td')
print(row_td)
type(row_td)
# Out:
# [<td><span class="mustPoint">*</span>验证码:</td>, <td>
# <div>
# <input autocomplete="off" class="verifyInp" id="verifyInp" placeholder="请输入验证码" type="text"/>
# <span class="verifyImg code" id="checkCode">
# </span>
# </div>
# </td>]
# bs4.element.ResultSet

# %%
str_cells = str(row_td)
cleantext = BeautifulSoup(str_cells, "lxml").get_text()
print(cleantext)
# Out:
# [*验证码:,
#
#
#
#
#
# ]

# %%
list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2)
print(clean2)
type(clean2)
# Out:
# [*验证码:,
#
#
#
#
#
# ]
# str

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.DataFrame(list_rows)
df.head(10)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  0
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               []
# 1  [\n当前筛选\n\n\n\r\n                      var getElementsByName = function (tag, name){\r\n                        var returns = document.getElementsByName(name);\r\n                        if(returns.length > 0) return returns;\r\n                        returns = new Array();\r\n                        var e = document.getElementsByTagName(tag);\r\n                        for(var i = 0; i < e.length; i++){\r\n                          if(e[i].getAttribute("name") == name){\r\n                            returns[returns.length] = e[i];\r\n                          }\r\n                        }\r\n                        return returns;\r\n                      };\r\n                      var MAR_TYPE_ID = '';\r\n                      var tableArr = getElementsByName('meta', 'channel');\r\n                      if(tableArr != null && tableArr.length > 0)\r\n                      {\r\n                        MAR_TYPE_ID = tableArr[0].content;\r\n                      }\r\n                    \n]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [\r\n                                        卷板\r\n                                      , \r\n                                        3.0*1520*C\r\n                                      , \r\n                                        2205/NO.1\r\n                                      , \r\n                                        酒钢\r\n                                      , \n\n, \n\n, \r\n                                        毛边\r\n                                      ]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [\r\n                                        卷板\r\n                                      , \r\n                                        4.0*1520*C\r\n                                      , \r\n                                        2205/NO.1\r\n                                      , \r\n                                        酒钢\r\n                                      , \n\n, \n\n, \r\n                                        毛边\r\n                                      ]
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [\r\n                                        卷板\r\n                                      , \r\n                                        5.0*1520*C\r\n                                      , \r\n                                        2205/NO.1\r\n                                      , \r\n                                        酒钢\r\n                                      , \n\n, \n\n, \r\n                                        毛边\r\n                                      ]
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [\r\n                                        卷板\r\n                                      , \r\n                                        6.0*1520*C\r\n                                      , \r\n                                        2205/NO.1\r\n                                      , \r\n                                        酒钢\r\n                                      , \n\n, \n\n, \r\n                                        毛边\r\n                                      ]
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [\r\n                                        卷板\r\n                                      , \r\n                                        4.0*1520*C\r\n                                      , \r\n                                        2205/NO.1\r\n                                      , \r\n                                        东方特钢\r\n                                      , \n\n, \n\n, \r\n                                        毛边\r\n                                      ]
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [\r\n                                        卷板\r\n                                      , \r\n                                        5.0*1520*C\r\n                                      , \r\n                                        2205/NO.1\r\n                                      , \r\n                                        东方特钢\r\n                                      , \n\n, \n\n, \r\n                                        毛边\r\n                                      ]
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [\r\n                                        卷板\r\n                                      , \r\n                                        6.0*1520*C\r\n                                      , \r\n                                        2205/NO.1\r\n                                      , \r\n                                        东方特钢\r\n                                      , \n\n, \n\n, \r\n                                        毛边\r\n                                      ]
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [\r\n                                        卷板\r\n                                      , \r\n                                        8.0*1520*C\r\n                                      , \r\n                                        2205/NO.1\r\n                                      , \r\n                                        东方特钢\r\n                                      , \n\n, \n\n, \r\n                                        毛边\r\n                                      ]

# %%
df1 = df[0].str.split(',', expand=True)
df1.head(10)
# Out:
#                                                                                            0  \
# 0                                                                                         []
# 1               [\n当前筛选\n\n\n\r\n                      var getElementsByName = function (tag
# 2  [\r\n                                        卷板\r\n
# 3  [\r\n                                        卷板\r\n
# 4  [\r\n                                        卷板\r\n
# 5  [\r\n                                        卷板\r\n
# 6  [\r\n                                        卷板\r\n
# 7  [\r\n                                        卷板\r\n
# 8  [\r\n                                        卷板\r\n
# 9  [\r\n                                        卷板\r\n
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               None
# 1   name){\r\n                        var returns = document.getElementsByName(name);\r\n                        if(returns.length > 0) return returns;\r\n                        returns = new Array();\r\n                        var e = document.getElementsByTagName(tag);\r\n                        for(var i = 0; i < e.length; i++){\r\n                          if(e[i].getAttribute("name") == name){\r\n                            returns[returns.length] = e[i];\r\n                          }\r\n                        }\r\n                        return returns;\r\n                      };\r\n                      var MAR_TYPE_ID = '';\r\n                      var tableArr = getElementsByName('meta'
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        3.0*1520*C\r\n
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        4.0*1520*C\r\n
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        5.0*1520*C\r\n
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        6.0*1520*C\r\n
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        4.0*1520*C\r\n
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        5.0*1520*C\r\n
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        6.0*1520*C\r\n
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        8.0*1520*C\r\n
#
#                                                                                                                                                                                                                                   2  \
# 0                                                                                                                                                                                                                              None
# 1   'channel');\r\n                      if(tableArr != null && tableArr.length > 0)\r\n                      {\r\n                        MAR_TYPE_ID = tableArr[0].content;\r\n                      }\r\n                    \n]
# 2                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 3                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 4                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 5                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 6                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 7                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 8                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 9                                                                                                                                   \r\n                                        2205/NO.1\r\n
#
#                                                                                              3  \
# 0                                                                                         None
# 1                                                                                         None
# 2     \r\n                                        酒钢\r\n
# 3     \r\n                                        酒钢\r\n
# 4     \r\n                                        酒钢\r\n
# 5     \r\n                                        酒钢\r\n
# 6   \r\n                                        东方特钢\r\n
# 7   \r\n                                        东方特钢\r\n
# 8   \r\n                                        东方特钢\r\n
# 9   \r\n                                        东方特钢\r\n
#
#        4      5  \
# 0   None   None
# 1   None   None
# 2   \n\n   \n\n
# 3   \n\n   \n\n
# 4   \n\n   \n\n
# 5   \n\n   \n\n
# 6   \n\n   \n\n
# 7   \n\n   \n\n
# 8   \n\n   \n\n
# 9   \n\n   \n\n
#
#                                                                                             6
# 0                                                                                        None
# 1                                                                                        None
# 2   \r\n                                        毛边\r\n                                      ]
# 3   \r\n                                        毛边\r\n                                      ]
# 4   \r\n                                        毛边\r\n                                      ]
# 5   \r\n                                        毛边\r\n                                      ]
# 6   \r\n                                        毛边\r\n                                      ]
# 7   \r\n                                        毛边\r\n                                      ]
# 8   \r\n                                        毛边\r\n                                      ]
# 9   \r\n                                        毛边\r\n                                      ]

# %%
df1[0] = df1[0].str.strip('[')
df1.head(10)
# Out:
#                                                                                           0  \
# 0                                                                                         ]
# 1               \n当前筛选\n\n\n\r\n                      var getElementsByName = function (tag
# 2  \r\n                                        卷板\r\n
# 3  \r\n                                        卷板\r\n
# 4  \r\n                                        卷板\r\n
# 5  \r\n                                        卷板\r\n
# 6  \r\n                                        卷板\r\n
# 7  \r\n                                        卷板\r\n
# 8  \r\n                                        卷板\r\n
# 9  \r\n                                        卷板\r\n
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               None
# 1   name){\r\n                        var returns = document.getElementsByName(name);\r\n                        if(returns.length > 0) return returns;\r\n                        returns = new Array();\r\n                        var e = document.getElementsByTagName(tag);\r\n                        for(var i = 0; i < e.length; i++){\r\n                          if(e[i].getAttribute("name") == name){\r\n                            returns[returns.length] = e[i];\r\n                          }\r\n                        }\r\n                        return returns;\r\n                      };\r\n                      var MAR_TYPE_ID = '';\r\n                      var tableArr = getElementsByName('meta'
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        3.0*1520*C\r\n
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        4.0*1520*C\r\n
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        5.0*1520*C\r\n
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        6.0*1520*C\r\n
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        4.0*1520*C\r\n
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        5.0*1520*C\r\n
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        6.0*1520*C\r\n
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        8.0*1520*C\r\n
#
#                                                                                                                                                                                                                                   2  \
# 0                                                                                                                                                                                                                              None
# 1   'channel');\r\n                      if(tableArr != null && tableArr.length > 0)\r\n                      {\r\n                        MAR_TYPE_ID = tableArr[0].content;\r\n                      }\r\n                    \n]
# 2                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 3                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 4                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 5                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 6                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 7                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 8                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 9                                                                                                                                   \r\n                                        2205/NO.1\r\n
#
#                                                                                              3  \
# 0                                                                                         None
# 1                                                                                         None
# 2     \r\n                                        酒钢\r\n
# 3     \r\n                                        酒钢\r\n
# 4     \r\n                                        酒钢\r\n
# 5     \r\n                                        酒钢\r\n
# 6   \r\n                                        东方特钢\r\n
# 7   \r\n                                        东方特钢\r\n
# 8   \r\n                                        东方特钢\r\n
# 9   \r\n                                        东方特钢\r\n
#
#        4      5  \
# 0   None   None
# 1   None   None
# 2   \n\n   \n\n
# 3   \n\n   \n\n
# 4   \n\n   \n\n
# 5   \n\n   \n\n
# 6   \n\n   \n\n
# 7   \n\n   \n\n
# 8   \n\n   \n\n
# 9   \n\n   \n\n
#
#                                                                                             6
# 0                                                                                        None
# 1                                                                                        None
# 2   \r\n                                        毛边\r\n                                      ]
# 3   \r\n                                        毛边\r\n                                      ]
# 4   \r\n                                        毛边\r\n                                      ]
# 5   \r\n                                        毛边\r\n                                      ]
# 6   \r\n                                        毛边\r\n                                      ]
# 7   \r\n                                        毛边\r\n                                      ]
# 8   \r\n                                        毛边\r\n                                      ]
# 9   \r\n                                        毛边\r\n                                      ]

# %%
col_labels = soup.find_all('th')

# %%
all_header = []
col_str = str(col_labels)
cleantext2 = BeautifulSoup(col_str, "lxml").get_text()
all_header.append(cleantext2)
print(all_header)
# Out:
# ['[\r\n                    钢种                     \n请筛选\n\n\n\n, \r\n                    规格                     \n请筛选\n\n\n\n, \r\n                    牌号                     \n请筛选\n\n\n\n, \r\n                    钢厂/产地                     \n请筛选\n\n\n\n, \r\n                    价格（元/吨）                   , \r\n                    涨跌                   , \r\n                    备注                   , \r\n              意见反馈\n]']

# %%
df2 = pd.DataFrame(all_header)
df2.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                          0
# 0  [\r\n                    钢种                     \n请筛选\n\n\n\n, \r\n                    规格                     \n请筛选\n\n\n\n, \r\n                    牌号                     \n请筛选\n\n\n\n, \r\n                    钢厂/产地                     \n请筛选\n\n\n\n, \r\n                    价格（元/吨）                   , \r\n                    涨跌                   , \r\n                    备注                   , \r\n              意见反馈\n]

# %%
df3 = df2[0].str.split(',', expand=True)
df3.head()
# Out:
#                                                                0  \
# 0  [\r\n                    钢种                     \n请筛选\n\n\n\n
#
#                                                                1  \
# 0   \r\n                    规格                     \n请筛选\n\n\n\n
#
#                                                                2  \
# 0   \r\n                    牌号                     \n请筛选\n\n\n\n
#
#                                                                   3  \
# 0   \r\n                    钢厂/产地                     \n请筛选\n\n\n\n
#
#                                                      4  \
# 0   \r\n                    价格（元/吨）
#
#                                                 5  \
# 0   \r\n                    涨跌
#
#                                                 6                           7
# 0   \r\n                    备注                      \r\n              意见反馈\n]

# %%
frames = [df3, df1]
df4 = pd.concat(frames)
df4.head(10)
# Out:
#                                                                                           0  \
# 0                             [\r\n                    钢种                     \n请筛选\n\n\n\n
# 0                                                                                         ]
# 1               \n当前筛选\n\n\n\r\n                      var getElementsByName = function (tag
# 2  \r\n                                        卷板\r\n
# 3  \r\n                                        卷板\r\n
# 4  \r\n                                        卷板\r\n
# 5  \r\n                                        卷板\r\n
# 6  \r\n                                        卷板\r\n
# 7  \r\n                                        卷板\r\n
# 8  \r\n                                        卷板\r\n
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       \r\n                    规格                     \n请筛选\n\n\n\n
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               None
# 1   name){\r\n                        var returns = document.getElementsByName(name);\r\n                        if(returns.length > 0) return returns;\r\n                        returns = new Array();\r\n                        var e = document.getElementsByTagName(tag);\r\n                        for(var i = 0; i < e.length; i++){\r\n                          if(e[i].getAttribute("name") == name){\r\n                            returns[returns.length] = e[i];\r\n                          }\r\n                        }\r\n                        return returns;\r\n                      };\r\n                      var MAR_TYPE_ID = '';\r\n                      var tableArr = getElementsByName('meta'
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        3.0*1520*C\r\n
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        4.0*1520*C\r\n
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        5.0*1520*C\r\n
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        6.0*1520*C\r\n
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        4.0*1520*C\r\n
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        5.0*1520*C\r\n
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        6.0*1520*C\r\n
#
#                                                                                                                                                                                                                                   2  \
# 0                                                                                                                                                                      \r\n                    牌号                     \n请筛选\n\n\n\n
# 0                                                                                                                                                                                                                              None
# 1   'channel');\r\n                      if(tableArr != null && tableArr.length > 0)\r\n                      {\r\n                        MAR_TYPE_ID = tableArr[0].content;\r\n                      }\r\n                    \n]
# 2                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 3                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 4                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 5                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 6                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 7                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 8                                                                                                                                   \r\n                                        2205/NO.1\r\n
#
#                                                                                              3  \
# 0                              \r\n                    钢厂/产地                     \n请筛选\n\n\n\n
# 0                                                                                         None
# 1                                                                                         None
# 2     \r\n                                        酒钢\r\n
# 3     \r\n                                        酒钢\r\n
# 4     \r\n                                        酒钢\r\n
# 5     \r\n                                        酒钢\r\n
# 6   \r\n                                        东方特钢\r\n
# 7   \r\n                                        东方特钢\r\n
# 8   \r\n                                        东方特钢\r\n
#
#                                                      4  \
# 0   \r\n                    价格（元/吨）
# 0                                                 None
# 1                                                 None
# 2                                                 \n\n
# 3                                                 \n\n
# 4                                                 \n\n
# 5                                                 \n\n
# 6                                                 \n\n
# 7                                                 \n\n
# 8                                                 \n\n
#
#                                                 5  \
# 0   \r\n                    涨跌
# 0                                            None
# 1                                            None
# 2                                            \n\n
# 3                                            \n\n
# 4                                            \n\n
# 5                                            \n\n
# 6                                            \n\n
# 7                                            \n\n
# 8                                            \n\n
#
#                                                                                             6  \
# 0                                               \r\n                    备注
# 0                                                                                        None
# 1                                                                                        None
# 2   \r\n                                        毛边\r\n                                      ]
# 3   \r\n                                        毛边\r\n                                      ]
# 4   \r\n                                        毛边\r\n                                      ]
# 5   \r\n                                        毛边\r\n                                      ]
# 6   \r\n                                        毛边\r\n                                      ]
# 7   \r\n                                        毛边\r\n                                      ]
# 8   \r\n                                        毛边\r\n                                      ]
#
#                             7
# 0   \r\n              意见反馈\n]
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN

# %%
df5 = df4.rename(columns=df4.iloc[0])
df5.head()
# Out:
#                               [\r\n                    钢种                     \n请筛选\n\n\n\n  \
# 0                             [\r\n                    钢种                     \n请筛选\n\n\n\n
# 0                                                                                         ]
# 1               \n当前筛选\n\n\n\r\n                      var getElementsByName = function (tag
# 2  \r\n                                        卷板\r\n
# 3  \r\n                                        卷板\r\n
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         \r\n                    规格                     \n请筛选\n\n\n\n  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       \r\n                    规格                     \n请筛选\n\n\n\n
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               None
# 1   name){\r\n                        var returns = document.getElementsByName(name);\r\n                        if(returns.length > 0) return returns;\r\n                        returns = new Array();\r\n                        var e = document.getElementsByTagName(tag);\r\n                        for(var i = 0; i < e.length; i++){\r\n                          if(e[i].getAttribute("name") == name){\r\n                            returns[returns.length] = e[i];\r\n                          }\r\n                        }\r\n                        return returns;\r\n                      };\r\n                      var MAR_TYPE_ID = '';\r\n                      var tableArr = getElementsByName('meta'
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        3.0*1520*C\r\n
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\n                                        4.0*1520*C\r\n
#
#                                                                                                                                                                        \r\n                    牌号                     \n请筛选\n\n\n\n  \
# 0                                                                                                                                                                      \r\n                    牌号                     \n请筛选\n\n\n\n
# 0                                                                                                                                                                                                                              None
# 1   'channel');\r\n                      if(tableArr != null && tableArr.length > 0)\r\n                      {\r\n                        MAR_TYPE_ID = tableArr[0].content;\r\n                      }\r\n                    \n]
# 2                                                                                                                                   \r\n                                        2205/NO.1\r\n
# 3                                                                                                                                   \r\n                                        2205/NO.1\r\n
#
#                              \r\n                    钢厂/产地                     \n请筛选\n\n\n\n  \
# 0                            \r\n                    钢厂/产地                     \n请筛选\n\n\n\n
# 0                                                                                       None
# 1                                                                                       None
# 2   \r\n                                        酒钢\r\n
# 3   \r\n                                        酒钢\r\n
#
#     \r\n                    价格（元/吨）                     \
# 0   \r\n                    价格（元/吨）
# 0                                                 None
# 1                                                 None
# 2                                                 \n\n
# 3                                                 \n\n
#
#     \r\n                    涨跌                     \
# 0   \r\n                    涨跌
# 0                                            None
# 1                                            None
# 2                                            \n\n
# 3                                            \n\n
#
#                                                 \r\n                    备注                     \
# 0                                               \r\n                    备注
# 0                                                                                        None
# 1                                                                                        None
# 2   \r\n                                        毛边\r\n                                      ]
# 3   \r\n                                        毛边\r\n                                      ]
#
#     \r\n              意见反馈\n]
# 0   \r\n              意见反馈\n]
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN

# %%
df5.info()
df5.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 18
# Data columns (total 8 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   [
#                     钢种
# 请筛选
#
#
#
#      20 non-null     object
#  1
#                     规格
# 请筛选
#
#
#
#      18 non-null     object
#  2
#                     牌号
# 请筛选
#
#
#
#      12 non-null     object
#  3
#                     钢厂/产地
# 请筛选
#
#
#
#   11 non-null     object
#  4
#                     价格（元/吨）                             11 non-null     object
#  5
#                     涨跌                                  11 non-null     object
#  6
#                     备注                                  11 non-null     object
#  7
#               意见反馈
# ]                                    1 non-null      object
# dtypes: object(8)
# memory usage: 1.4+ KB
# (20, 8)
